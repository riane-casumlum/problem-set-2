# %% [markdown]
# # Dam Locations and Population Density (South Africa)

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
# Setting Global File Path

## define global file path
file_path = "C://Users//riane//Downloads//02_GitHub//problem-set-2"

## define global data path
data_path = file_path + "//01_Dataset"

## define global country path
safrica = data_path + "//South Africa"
ethiopia = data_path + "//Ethiopia"
vietnam = data_path + "//Vietnam"
brazil = data_path + "//Brazil"

# %%
# Loading data
safrica_shp = gpd.read_file(safrica + "//SA_MDB_Local_Municipal_Boundary_2018//MDB_Local_Municipal_Boundary_2018.shp")
safrica_dams = pd.read_excel(safrica + "//Dams_south_africa.xlsx")
safrica_popu = pd.read_excel(safrica + "//population_africa.xlsx")

# %% [markdown]
# ## Data Cleaning

# %%
# Inspecting data
safrica_shp
# Out:
#      FID  OBJECTID PROVINCE CATEGORY                CAT2   CAT_B  \
# 0      1       197       WC        B  Local Municipality   WC032
# 1      2       138       WC        B  Local Municipality   WC033
# 2      3       160       WC        B  Local Municipality   WC031
# 3      4       142       WC        B  Local Municipality   WC043
# 4      5       141       WC        B  Local Municipality   WC042
# ..   ...       ...      ...      ...                 ...     ...
# 208  209       208      LIM        B  Local Municipality  LIM345
# 209  210       206      LIM        B  Local Municipality  LIM343
# 210  211       200      LIM        B  Local Municipality  LIM351
# 211  212       205      LIM        B  Local Municipality  LIM341
# 212  213       153      KZN        B  Local Municipality  KZN276
#
#             MUNICNAME                   NAMECODE  \
# 0          Overstrand         Overstrand (WC032)
# 1        Cape Agulhas       Cape Agulhas (WC033)
# 2     Theewaterskloof    Theewaterskloof (WC031)
# 3          Mossel Bay         Mossel Bay (WC043)
# 4            Hessequa           Hessequa (WC042)
# ..                ...                        ...
# 208   Collins Chabane   Collins Chabane (LIM345)
# 209         Thulamela         Thulamela (LIM343)
# 210          Blouberg          Blouberg (LIM351)
# 211            Musina            Musina (LIM341)
# 212  Big Five Hlabisa  Big Five Hlabisa (KZN276)
#
#                                MAP_TITLE DISTRICT    DISTRICT_N       DATE  \
# 0          Overstrand Local Municipality      DC3      Overberg 2019-06-25
# 1        Cape Agulhas Local Municipality      DC3      Overberg 2019-06-25
# 2     Theewaterskloof Local Municipality      DC3      Overberg 2019-06-25
# 3          Mossel Bay Local Municipality      DC4  Garden Route 2019-06-25
# 4            Hessequa Local Municipality      DC4  Garden Route 2019-06-25
# ..                                   ...      ...           ...        ...
# 208   Collins Chabane Local Municipality     DC34        Vhembe 2019-06-25
# 209         Thulamela Local Municipality     DC34        Vhembe 2019-06-25
# 210          Blouberg Local Municipality     DC35     Capricorn 2019-06-25
# 211            Musina Local Municipality     DC34        Vhembe 2019-06-25
# 212  Big Five Hlabisa Local Municipality     DC27  Umkhanyakude 2019-06-25
#
#        Shape__Are     Shape__Len  \
# 0    2.470202e+09  503100.219054
# 1    5.121204e+09  510469.485052
# 2    4.774032e+09  407619.924636
# 3    2.921636e+09  361538.907987
# 4    8.388296e+09  609407.058375
# ..            ...            ...
# 208  5.931389e+09  612925.637183
# 209  3.122493e+09  352761.996820
# 210  1.130638e+10  568573.089745
# 211  1.217129e+10  820095.819612
# 212  4.470828e+09  517290.477529
#
#                                               geometry
# 0    MULTIPOLYGON (((19.41807 -34.68668, 19.41807 -...
# 1    POLYGON ((20.06351 -34.21699, 20.06491 -34.233...
# 2    POLYGON ((19.2974 -33.88968, 19.31055 -33.9137...
# 3    POLYGON ((22.12817 -33.85624, 22.13423 -33.869...
# 4    POLYGON ((21.74781 -33.81114, 21.74785 -33.811...
# ..                                                 ...
# 208  POLYGON ((31.3449 -22.53453, 31.34739 -22.5420...
# 209  POLYGON ((30.91065 -22.47558, 30.91192 -22.475...
# 210  POLYGON ((28.87529 -22.44745, 28.8773 -22.4474...
# 211  POLYGON ((29.67528 -22.13901, 29.67583 -22.139...
# 212  POLYGON ((32.4644 -27.65302, 32.46415 -27.6542...
#
# [213 rows x 15 columns]

# %%
# Inspecting data
safrica_dams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10312 entries, 0 to 10311
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name of dam    10311 non-null  object
#  1   Latitude deg   10310 non-null  float64
#  2   Lat min        10310 non-null  float64
#  3   Lat sec        10310 non-null  float64
#  4   Longitude deg  10310 non-null  float64
#  5   Long min       10310 non-null  float64
#  6   Long sec       10310 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 564.1+ KB

# %%
# Inspecting data
safrica_popu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Municipality▲   213 non-null    object
#  1   Own             213 non-null    object
#  2   Province        213 non-null    object
#  3   Capital         212 non-null    object
#  4   Area            213 non-null    object
#  5   Population      213 non-null    object
#  6   Density         213 non-null    object
#  7   Municipality    213 non-null    object
# dtypes: object(8)
# memory usage: 13.4+ KB

# %%
# Checking for NA
safrica_popu.isna().sum()
# Out:
# Municipality▲     0
# Own               0
# Province          0
# Capital           1
# Area              0
# Population        0
# Density           0
# dtype: int64

# %%
# Cleaning data
safrica_popu['Municipality'] = safrica_popu['Municipality▲'].str.replace('\xa0', '', regex=False).str.strip().str.upper()
safrica_shp['MUNICNAME'] = safrica_shp['MUNICNAME'].str.strip().str.upper()

# %%
# Comparing municipality names

## make uppercase
safrica_shp['MUNICNAME'].str.upper()
safrica_popu['Municipality'].str.upper()

## 
muni_shp = set(safrica_shp['MUNICNAME'].unique())
muni_popu = set(safrica_popu['Municipality'].unique())

# Print counts
print("Unique in shapefile:", len(muni_shp))
print("Unique in population file:", len(muni_popu))

# Find common and missing municipalities
print("In shapefile not in popu:", muni_shp - muni_popu)
print("In popu not in shapefile:", muni_popu - muni_shp)
# Out:
# Unique in shapefile: 212
# Unique in population file: 212
# In shapefile not in popu: set()
# In popu not in shapefile: set()

# %%
# Replacing col values to match
replacements = {
    'KAGISANO/MOLOPO': 'KAGISANO-MOLOPO', 
    'DR BEYERS NAUDÉ': 'DR BEYERS NAUDE', 
    'MALUTI A PHOFUNG': 'MALUTI-A-PHOFUNG', 
    'KHEIS': '!KHEIS', 
    'MANGAUNG- BLOEMFONTEIN': 'MANGAUNG', 
    'CITY OF TSHWANE- PRETORIA': 'CITY OF TSHWANE', 
    'ETHEKWINI- DURBAN': 'ETHEKWINI', 
    'STEVE TSHWETE- MIDDELBURG': 'STEVE TSHWETE', 
    'KHAI MA': 'KHÂI-MA', 
    'BUFFALO CITY- EAST LONDON': 'BUFFALO CITY', 
    'BITOU - PLETTENBERG BAY': 'BITOU', 
    'MADIBENG': 'LOCAL MUNICIPALITY OF MADIBENG', 
    'PIXLEY KA SEME': 'DR PIXLEY KA ISAKA SEME', 
    'JOE MOROLONG(MOSHAWENG)': 'JOE MOROLONG', 
    'NQUTHU': 'NQUTU', 
    'engcobo': 'DR AB XUMA', 
    'ALBERT LUTHULI': 'CHIEF ALBERT LUTHULI', 
    'RAND WEST CITY- RANDFONTEIN': 'RAND WEST CITY', 
    'CITY OF MATLOSANA- KLERKSDORP': 'CITY OF MATLOSANA', 
    'KAI GARIB':'KAI !GARIB', 
    'NELSON MANDELA BAY- PORT ELIZABETH': 'NELSON MANDELA BAY'
}

safrica_popu['Municipality'] = safrica_popu['Municipality'].replace(replacements)

# %% [markdown]
# ## Preparation

# %%
# Dropping unnecessary columns
safrica_pdensity = safrica_popu[['Municipality', 'Density']].copy()

# Change ',' to '.' and convert to float
safrica_pdensity['Density'] = (
    safrica_pdensity['Density']
    .str.replace(' ', '')
    .str.replace(',', '.')
    .astype(float)
)

safrica_pdensity
# Out:
#                   Municipality  Density
# 0                    ABAQULUSI     57.3
# 1         CHIEF ALBERT LUTHULI     44.6
# 2                  ALFRED DUMA    110.3
# 3                    AMAHLATHI     25.7
# 4                BA-PHALABORWA     25.2
# ..                         ...      ...
# 208                  UPHONGOLO     48.7
# 209              VICTOR KHANYE     67.7
# 210              WALTER SISULU      7.9
# 211  WINNIE MADIKIZELA-MANDELA    144.9
# 212                 WITZENBERG      9.6
#
# [213 rows x 2 columns]

# %%
# Merging popu data to shp
safrica_shp_density = safrica_shp.merge(
    safrica_pdensity,
    left_on='MUNICNAME',
    right_on='Municipality',
    how='left'  # or 'inner' if you want only matches
)

safrica_shp_density
# Out:
#      FID  OBJECTID PROVINCE CATEGORY                CAT2   CAT_B  \
# 0      1       197       WC        B  Local Municipality   WC032
# 1      2       138       WC        B  Local Municipality   WC033
# 2      3       160       WC        B  Local Municipality   WC031
# 3      4       142       WC        B  Local Municipality   WC043
# 4      5       141       WC        B  Local Municipality   WC042
# ..   ...       ...      ...      ...                 ...     ...
# 210  209       208      LIM        B  Local Municipality  LIM345
# 211  210       206      LIM        B  Local Municipality  LIM343
# 212  211       200      LIM        B  Local Municipality  LIM351
# 213  212       205      LIM        B  Local Municipality  LIM341
# 214  213       153      KZN        B  Local Municipality  KZN276
#
#             MUNICNAME                   NAMECODE  \
# 0          OVERSTRAND         Overstrand (WC032)
# 1        CAPE AGULHAS       Cape Agulhas (WC033)
# 2     THEEWATERSKLOOF    Theewaterskloof (WC031)
# 3          MOSSEL BAY         Mossel Bay (WC043)
# 4            HESSEQUA           Hessequa (WC042)
# ..                ...                        ...
# 210   COLLINS CHABANE   Collins Chabane (LIM345)
# 211         THULAMELA         Thulamela (LIM343)
# 212          BLOUBERG          Blouberg (LIM351)
# 213            MUSINA            Musina (LIM341)
# 214  BIG FIVE HLABISA  Big Five Hlabisa (KZN276)
#
#                                MAP_TITLE DISTRICT    DISTRICT_N       DATE  \
# 0          Overstrand Local Municipality      DC3      Overberg 2019-06-25
# 1        Cape Agulhas Local Municipality      DC3      Overberg 2019-06-25
# 2     Theewaterskloof Local Municipality      DC3      Overberg 2019-06-25
# 3          Mossel Bay Local Municipality      DC4  Garden Route 2019-06-25
# 4            Hessequa Local Municipality      DC4  Garden Route 2019-06-25
# ..                                   ...      ...           ...        ...
# 210   Collins Chabane Local Municipality     DC34        Vhembe 2019-06-25
# 211         Thulamela Local Municipality     DC34        Vhembe 2019-06-25
# 212          Blouberg Local Municipality     DC35     Capricorn 2019-06-25
# 213            Musina Local Municipality     DC34        Vhembe 2019-06-25
# 214  Big Five Hlabisa Local Municipality     DC27  Umkhanyakude 2019-06-25
#
#        Shape__Are     Shape__Len  \
# 0    2.470202e+09  503100.219054
# 1    5.121204e+09  510469.485052
# 2    4.774032e+09  407619.924636
# 3    2.921636e+09  361538.907987
# 4    8.388296e+09  609407.058375
# ..            ...            ...
# 210  5.931389e+09  612925.637183
# 211  3.122493e+09  352761.996820
# 212  1.130638e+10  568573.089745
# 213  1.217129e+10  820095.819612
# 214  4.470828e+09  517290.477529
#
#                                               geometry      Municipality  \
# 0    MULTIPOLYGON (((19.41807 -34.68668, 19.41807 -...        OVERSTRAND
# 1    POLYGON ((20.06351 -34.21699, 20.06491 -34.233...      CAPE AGULHAS
# 2    POLYGON ((19.2974 -33.88968, 19.31055 -33.9137...   THEEWATERSKLOOF
# 3    POLYGON ((22.12817 -33.85624, 22.13423 -33.869...        MOSSEL BAY
# 4    POLYGON ((21.74781 -33.81114, 21.74785 -33.811...          HESSEQUA
# ..                                                 ...               ...
# 210  POLYGON ((31.3449 -22.53453, 31.34739 -22.5420...   COLLINS CHABANE
# 211  POLYGON ((30.91065 -22.47558, 30.91192 -22.475...         THULAMELA
# 212  POLYGON ((28.87529 -22.44745, 28.8773 -22.4474...          BLOUBERG
# 213  POLYGON ((29.67528 -22.13901, 29.67583 -22.139...            MUSINA
# 214  POLYGON ((32.4644 -27.65302, 32.46415 -27.6542...  BIG FIVE HLABISA
#
#      Density
# 0       79.1
# 1       11.6
# 2       42.8
# 3       70.0
# 4       12.5
# ..       ...
# 210     88.7
# 211    218.0
# 212     20.1
# 213     12.7
# 214     38.0
#
# [215 rows x 17 columns]

# %%
# Convert to decimal degree 
def dms_to_dd(degree, minute, second):
    return degree + (minute / 60) + (second / 3600)

safrica_dams['lat_dd'] = dms_to_dd(safrica_dams['Latitude deg'], safrica_dams['Lat min'], safrica_dams['Lat sec'])
safrica_dams['lon_dd'] = dms_to_dd(safrica_dams['Longitude deg'], safrica_dams['Long min'], safrica_dams['Long sec'])

# Change sign of lat
safrica_dams['lat_dd'] = -safrica_dams['lat_dd'].abs()

safrica_dams
# Out:
#              Name of dam  Latitude deg  Lat min  Lat sec  Longitude deg  \
# 0           NGOTWANE DAM          25.0     11.0     54.0           25.0
# 1          MAKGOPANE DAM          25.0      5.0     54.2           25.0
# 2        ROODEKOPJES DAM          25.0     24.0     24.0           27.0
# 3      HARTBEESPOORT DAM          25.0     43.0     32.3           27.0
# 4       BUFFELSPOORT DAM          25.0     46.0     49.5           27.0
# ...                  ...           ...      ...      ...            ...
# 10307      TSHAKHUMA DAM          23.0      1.0     58.0           30.0
# 10308   KORENTEPOORT DAM          34.0      0.0     17.4           21.0
# 10309     GRASSRIDGE DAM          31.0     46.0      4.2           25.0
# 10310     KNELLPOORT DAM          29.0     46.0     54.4           26.0
# 10311  GLEN MELVILLE DAM          33.0     11.0     45.0           26.0
#
#        Long min  Long sec     lat_dd     lon_dd                   geometry
# 0          48.0      48.0 -25.198333  25.813333  POINT (25.81333 25.19833)
# 1          52.0      57.0 -25.098389  25.882500   POINT (25.8825 25.09839)
# 2          34.0      39.0 -25.406667  27.577500   POINT (27.5775 25.40667)
# 3          50.0      54.1 -25.725639  27.848361  POINT (27.84836 25.72564)
# 4          29.0      14.5 -25.780417  27.487361  POINT (27.48736 25.78042)
# ...         ...       ...        ...        ...                        ...
# 10307      16.0      55.0 -23.032778  30.281944  POINT (30.28194 23.03278)
# 10308       9.0      56.4 -34.004833  21.165667  POINT (21.16567 34.00483)
# 10309      27.0      57.9 -31.767833  25.466083  POINT (25.46608 31.76783)
# 10310      53.0      19.2 -29.781778  26.888667  POINT (26.88867 29.78178)
# 10311      39.0      19.0 -33.195833  26.655278  POINT (26.65528 33.19583)
#
# [10312 rows x 10 columns]

# %%
# Plot the density and dam locations
safrica_dams = gpd.GeoDataFrame(
    safrica_dams,
    geometry=gpd.points_from_xy(safrica_dams['lon_dd'], safrica_dams['lat_dd']),
    crs="EPSG:4326"  
)

safrica_shp_density_proj = safrica_shp_density.to_crs(epsg=32735)
safrica_dams_proj = safrica_dams.to_crs(safrica_shp_density_proj.crs)

# keep only dams within South Africa
dams_within_sa = gpd.sjoin(
    safrica_dams_proj,
    safrica_shp_density_proj[['geometry']],  
    how="inner",
    predicate="within"
)

fig, ax = plt.subplots(figsize=(10, 10))

# Base map in light gray
safrica_shp_density_proj.plot(ax=ax, edgecolor='white', facecolor='lightgray')

# Choropleth overlay
safrica_shp_density_proj.plot(
    ax=ax,
    column='Density',
    cmap='OrRd',
    linewidth=0.1,
    legend=False,
    vmax=safrica_shp_density_proj['Density'].quantile(0.93)
)

# Dam points in black
dams_within_sa.plot(ax=ax, color='black', markersize=5)

# Adjust gradient
cax = fig.add_axes([0.92, 0.2, 0.02, 0.6])  

# Plot of colorbar on the custom axis
sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=0, vmax=vmax))
sm._A = []
cb = fig.colorbar(sm, cax=cax)
cb.set_label('Population Density')

ax.set_aspect('equal')
fig.suptitle('Choropleth Map Of Population Density with Dam Locations', x=0.6, y=0.95, fontsize=14)
ax.set_axis_off()
plt.show()

# %% [markdown]
# # Population Density and ERSS Sample Villages (Ethiopia)
# Darker regions represent high density while lighter ones represent less dense regions.
# Major roads are the ones with thicker lines while the high-voltage electricity grid are the thinner, straighter lines.

# %%
# Loading data
ethiopia_shp = gpd.read_file(ethiopia + "//Ethiopia_AdminBoundaries-shp//Ethiopia_AdminBoundaries.shp")
ethiopia_gen = gpd.read_file(ethiopia + "//Ethiopia_-_generators-shp//Ethiopia_-_generators.shp")
ethiopia_roads = gpd.read_file(ethiopia + "//ethiopia_roads//Ethiopia_Roads.shp")
ethiopia_transmission = gpd.read_file(ethiopia + "//Ethiopia-electricity-transmission-network//Ethiopia Electricity Transmission Network.shp")
ethiopia_popu = pd.read_csv(ethiopia + "//cod_population_admin2.csv", low_memory=False)
# Out:
# C:\Users\riane\anaconda3\envs\ds4upse\Lib\site-packages\pyogrio\raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured LineString' is converted to 'LineString'
#   return ogr_read(

# %%
ethiopia_popu
# Out:
#                   ISO3                       Country  ADM1_PCODE   ADM1_NAME  \
# 0        #country+code                 #country+name  #adm1+code  #adm1+name
# 1                  AGO                        Angola        AO01       Bengo
# 2                  AGO                        Angola        AO01       Bengo
# 3                  AGO                        Angola        AO01       Bengo
# 4                  AGO                        Angola        AO01       Bengo
# ...                ...                           ...         ...         ...
# 1006487            VIR  United States Virgin Islands       VI010   St. Croix
# 1006488            VIR  United States Virgin Islands       VI010   St. Croix
# 1006489            VIR  United States Virgin Islands       VI010   St. Croix
# 1006490            VIR  United States Virgin Islands       VI010   St. Croix
# 1006491            VIR  United States Virgin Islands       VI010   St. Croix
#
#          ADM2_PCODE   ADM2_NAME  ADM3_PCODE   ADM3_NAME  ADM4_PCODE  \
# 0        #adm2+code  #adm2+name  #adm3+code  #adm3+name  #adm4+code
# 1           AO01001      Ambriz         NaN         NaN         NaN
# 2           AO01001      Ambriz         NaN         NaN         NaN
# 3           AO01001      Ambriz         NaN         NaN         NaN
# 4           AO01001      Ambriz         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 1006487  VI01071200   Sion Farm         NaN         NaN         NaN
# 1006488  VI01071200   Sion Farm         NaN         NaN         NaN
# 1006489  VI01071200   Sion Farm         NaN         NaN         NaN
# 1006490  VI01071200   Sion Farm         NaN         NaN         NaN
# 1006491  VI01071200   Sion Farm         NaN         NaN         NaN
#
#           ADM4_NAME   Population_group   Gender   Age_range   Age_min  \
# 0        #adm4+name  #population+group  #gender  #age+range  #age+min
# 1               NaN               F_TL        f         all       NaN
# 2               NaN               M_TL        m         all       NaN
# 3               NaN               T_TL      all         all       NaN
# 4               NaN            F_00_04        f         0-4         0
# ...             ...                ...      ...         ...       ...
# 1006487         NaN            M_65_69        m       65-69        65
# 1006488         NaN            M_70_74        m       70-74        70
# 1006489         NaN            M_75_79        m       75-79        75
# 1006490         NaN            M_80_84        m       80-84        80
# 1006491         NaN           M_85PLUS        m         85+        85
#
#           Age_max   Population Reference_year  \
# 0        #age+max  #population     #date+year
# 1             NaN        15102           2024
# 2             NaN        17667           2024
# 3             NaN        32769           2024
# 4               4         2877           2024
# ...           ...          ...            ...
# 1006487        69          353           2010
# 1006488        74          237           2010
# 1006489        79          119           2010
# 1006490        84           88           2010
# 1006491       NaN           60           2010
#
#                                                     Source  \
# 0                                             #meta+source
# 1        Institut National de la Statistique et de l'An...
# 2        Institut National de la Statistique et de l'An...
# 3        Institut National de la Statistique et de l'An...
# 4        Institut National de la Statistique et de l'An...
# ...                                                    ...
# 1006487                 United States Bureau of the Census
# 1006488                 United States Bureau of the Census
# 1006489                 United States Bureau of the Census
# 1006490                 United States Bureau of the Census
# 1006491                 United States Bureau of the Census
#
#                                           Contributor
# 0                                   #meta+contributor
# 1                                               UNFPA
# 2                                               UNFPA
# 3                                               UNFPA
# 4                                               UNFPA
# ...                                               ...
# 1006487  OCHA Latin America and the Caribbean (ROLAC)
# 1006488  OCHA Latin America and the Caribbean (ROLAC)
# 1006489  OCHA Latin America and the Caribbean (ROLAC)
# 1006490  OCHA Latin America and the Caribbean (ROLAC)
# 1006491  OCHA Latin America and the Caribbean (ROLAC)
#
# [1006492 rows x 19 columns]

# %%
ethiopia_proj = ethiopia_shp.to_crs(epsg=4326)
ethiopia_roads_proj = ethiopia_roads.to_crs(epsg=4326)
ethiopia_gen_proj = ethiopia_gen.to_crs(epsg=4326)
fig, ax = plt.subplots(figsize=(10, 10))

# Base map in light gray
ethiopia_proj.plot(ax=ax, edgecolor='white', facecolor='lightgray')

# Roads black line
ethiopia_roads_proj.plot(ax=ax, color='black', linewidth=2)

# Generators
ethiopia_gen_proj.plot(ax=ax, edgecolor='black', facecolor='white')

ethiopia_transmission.plot(ax=ax, color='red', linewidth=1)
# Out:
# <Axes: >

# %%
ethiopia_proj = ethiopia_shp.to_crs(epsg=4326)
ethiopia_roads_proj = ethiopia_roads.to_crs(epsg=4326)
fig, ax = plt.subplots(figsize=(10, 10))
ethiopia_shp.plot(ax=ax, edgecolor='black', facecolor='lightgray')
plt.title("Ethiopia Base Map")
plt.show()
